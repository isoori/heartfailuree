# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

from sklearn.model_selection import train_test_split,RandomizedSearchCV,GridSearchCV,cross_val_score
from sklearn.linear_model import LogisticRegression,RidgeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import f1_score,accuracy_score,recall_score,confusion_matrix,precision_score,plot_roc_curve

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df['ChestPainType'].value_counts()
# Out:
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64

# %%
df['ChestPainType']= pd.Categorical(df['ChestPainType']).codes

# %%
df['RestingECG']= pd.Categorical(df['RestingECG']).codes

# %%
df['ExerciseAngina']= pd.Categorical(df['ExerciseAngina']).codes

# %%
df['ST_Slope']= pd.Categorical(df['ST_Slope']).codes

# %%
df['Sex'] = pd.Categorical(df['Sex']).codes

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140          289          0           1
# 1   49    0              2        160          180          0           1
# 2   37    1              1        130          283          0           2
# 3   48    0              0        138          214          0           1
# 4   54    1              2        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         2             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         2             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         2             0

# %%
features = df.drop('HeartDisease',axis=1)
target = df['HeartDisease']
x_train , x_test , y_train, y_test = train_test_split(features,target,test_size=0.2,random_state=42)

# %%
models = {
    'LogisticRegression':LogisticRegression(max_iter=1000),
    'Ridge' : RidgeClassifier(),
    'DecisionTree':DecisionTreeClassifier(),
    'RandomForest':RandomForestClassifier(n_estimators=100),
    'XGB':XGBClassifier(),
    'KNeighbors':KNeighborsClassifier(),
    'SVC':SVC()
}
result = pd.DataFrame(index=['SCORE','ACCURACY','PRECISION',"RECALL"])

def regressions(models,x_train,y_train,x_test,y_test):
    for name,model in models.items():
        model.fit(x_train,y_train)
        prediction = model.predict(x_test)
        #score = f1_score(y_true=y_test,y_pred=prediction)
        #accuracy = accuracy_score(y_true=y_test,y_pred=prediction)
        #precision = precision_score(y_true=y_test,y_pred=prediction)
        #recall = recall_score(y_true=y_test,y_pred=prediction)
        clf = model
        cv_acc = cross_val_score(clf,
                        features,
                        target,
                        cv=5,
                        scoring='accuracy')
        cv_score = cross_val_score(clf,
                        features,
                        target,
                        cv=5,
                        scoring='f1')
        cv_precision = cross_val_score(clf,
                        features,
                        target,
                        cv=5,
                        scoring='precision')
        cv_recall = cross_val_score(clf,
                        features,
                        target,
                        cv=5,
                        scoring='recall')
        plot_roc_curve(clf,x_test,y_test)
        result[f'{name}'] = [np.round(cv_score.mean(),3),np.round(cv_acc.mean(),3),np.round(cv_precision.mean(),3),np.round(cv_precision.mean(),3)]
        plt.show()
    return result

# %%
regressions(models,x_train,y_train,x_test,y_test)
# Out:
# C:\Users\IsoorI\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
# C:\Users\IsoorI\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
# C:\Users\IsoorI\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# ...

# %%
n_estimators = [100,200,300,500,1000]
max_depth = [None,2,5,10]
min_samples_split = [2,5,10]
min_samples_leaf = [1,2,5]
max_features = ['auto','log2','sqrt']

params = {
    "max_features":max_features,
    'max_depth':max_depth,
    'min_samples_split':min_samples_split,
    'min_samples_leaf':min_samples_leaf,
    'n_estimators':n_estimators
}



rf = RandomForestClassifier()
rf_grid = RandomizedSearchCV(estimator=rf,param_distributions=params,n_iter=100,cv=3,verbose=2)
rf_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.3s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300; total time=   0.3s
# ...

# %%
rf_grid.best_params_
# Out:
# {'n_estimators': 300,
#  'min_samples_split': 2,
#  'min_samples_leaf': 5,
#  'max_features': 'sqrt',
#  'max_depth': 10}

# %%
RF=RandomForestClassifier(n_estimators=300,max_depth =10,max_features ='sqrt',min_samples_leaf=5,min_samples_split=2)
RF.fit(x_train,y_train)
new_pred = RF.predict(x_test)
score = f1_score(y_true=y_test,y_pred=new_pred)
accuracy = accuracy_score(y_true=y_test,y_pred=new_pred)
precision = precision_score(y_true=y_test,y_pred=new_pred)
recall = recall_score(y_true=y_test,y_pred=new_pred)
result['Randomized_RF'] = [np.round(score,3),np.round(accuracy,3),np.round(precision,3),np.round(recall,3)]

# %%
result
# Out:
#            LogisticRegression  Ridge  DecisionTree  RandomForest    XGB  \
# SCORE                   0.819  0.821         0.753         0.839  0.818
# ACCURACY                0.806  0.812         0.742         0.833  0.803
# PRECISION               0.846  0.858         0.805         0.850  0.837
# RECALL                  0.846  0.858         0.805         0.850  0.837
#
#            KNeighbors    SVC  Randomized_RF
# SCORE           0.676  0.685          0.897
# ACCURACY        0.662  0.684          0.880
# PRECISION       0.714  0.750          0.897
# RECALL          0.714  0.750          0.897

# %%
n_estimators = [100,200,300,500,1000]
max_depth = [None,2,5,10]
min_samples_split = [2,5,10]
min_samples_leaf = [1,2,5]
max_features = ['auto','log2','sqrt']

params = {
    "max_features":max_features,
    'max_depth':max_depth,
    'min_samples_split':min_samples_split,
    'min_samples_leaf':min_samples_leaf,
    'n_estimators':n_estimators
}



rf = RandomForestClassifier()
rf_grid = GridSearchCV(estimator=rf,param_grid=params,cv=3,verbose=2)
rf_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 540 candidates, totalling 1620 fits
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.3s
# ...

# %%
rf_grid.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 'auto',
#  'min_samples_leaf': 2,
#  'min_samples_split': 5,
#  'n_estimators': 200}

# %%
RFG=RandomForestClassifier(n_estimators=200,max_depth =5,max_features ='auto',min_samples_leaf=2,min_samples_split=5)
RFG.fit(x_train,y_train)
new_predd = RFG.predict(x_test)
score = f1_score(y_true=y_test,y_pred=new_predd)
accuracy = accuracy_score(y_true=y_test,y_pred=new_predd)
precision = precision_score(y_true=y_test,y_pred=new_predd)
recall = recall_score(y_true=y_test,y_pred=new_predd)
result['Grid_RF'] = [np.round(score,3),np.round(accuracy,3),np.round(precision,3),np.round(recall,3)]

# %%
cm = sns.light_palette("green", as_cmap=True)

result.T.style.highlight_max(color='lightgreen')
# Out:
# <style type="text/css">
# #T_449f0_row7_col0, #T_449f0_row7_col1, #T_449f0_row7_col2, #T_449f0_row7_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_449f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_449f0_level0_col0" class="col_heading level0 col0" >SCORE</th>
#       <th id="T_449f0_level0_col1" class="col_heading level0 col1" >ACCURACY</th>
#       <th id="T_449f0_level0_col2" class="col_heading level0 col2" >PRECISION</th>
#       <th id="T_449f0_level0_col3" class="col_heading level0 col3" >RECALL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_449f0_level0_row0" class="row_heading level0 row0" >LogisticRegression</th>
#       <td id="T_449f0_row0_col0" class="data row0 col0" >0.819000</td>
#       <td id="T_449f0_row0_col1" class="data row0 col1" >0.806000</td>
#       <td id="T_449f0_row0_col2" class="data row0 col2" >0.846000</td>
# ...

# %%
df.corrwith(df['HeartDisease']).sort_values(ascending=False)
# Out:
# HeartDisease      1.000000
# ExerciseAngina    0.494282
# Oldpeak           0.403951
# Sex               0.305445
# Age               0.282039
# FastingBS         0.267291
# RestingBP         0.107589
# RestingECG        0.057384
# Cholesterol      -0.232741
# ChestPainType    -0.386828
# MaxHR            -0.400421
# ST_Slope         -0.558771
# dtype: float64

# %%
features2 = df.drop(['RestingECG','HeartDisease'],axis=1)
target2 = df['HeartDisease']
x_train , x_test , y_train, y_test = train_test_split(features2,target2,test_size=0.2,random_state=42)
models = {
    'LogisticRegression':LogisticRegression(max_iter=1000),
    'Ridge' : RidgeClassifier(),
    'DecisionTree':DecisionTreeClassifier(),
    'RandomForest':RandomForestClassifier(n_estimators=100),
    'XGB':XGBClassifier(),
    'KNeighbors':KNeighborsClassifier(),
    'SVC':SVC()
}
result2 = pd.DataFrame(index=['SCORE','ACCURACY','PRECISION',"RECALL"])

def regressions(models,x_train,y_train,x_test,y_test):
    for name,model in models.items():
        model.fit(x_train,y_train)
        prediction = model.predict(x_test)
        #score = f1_score(y_true=y_test,y_pred=prediction)
        #accuracy = accuracy_score(y_true=y_test,y_pred=prediction)
        #precision = precision_score(y_true=y_test,y_pred=prediction)
        #recall = recall_score(y_true=y_test,y_pred=prediction)
        clf = model
        cv_acc = cross_val_score(clf,
                        features2,
                        target2,
                        cv=5,
                        scoring='accuracy')
        cv_score = cross_val_score(clf,
                        features2,
                        target2,
                        cv=5,
                        scoring='f1')
        cv_precision = cross_val_score(clf,
                        features2,
                        target2,
                        cv=5,
                        scoring='precision')
        cv_recall = cross_val_score(clf,
                        features2,
                        target2,
                        cv=5,
                        scoring='recall')
        plot_roc_curve(clf,x_test,y_test)
        cn = confusion_matrix(y_test,prediction)
        plt.xlabel('True Label')
        plt.ylabel("Predicted Label")
        plt.show()
        sns.heatmap(cn,annot=True)
        result2[f'{name}'] = [np.round(cv_score.mean(),3),np.round(cv_acc.mean(),3),np.round(cv_precision.mean(),3),np.round(cv_precision.mean(),3)]
        plt.show()
    return result2

# %%
regressions(models,x_train,y_train,x_test,y_test)
# Out:
# C:\Users\IsoorI\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
# C:\Users\IsoorI\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
# C:\Users\IsoorI\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# ...

# %%
n_estimators = [100,200,300,500,1000]
max_depth = [None,2,5,10]
min_samples_split = [2,5,10]
min_samples_leaf = [1,2,5]
max_features = ['auto','log2','sqrt']

params = {
    "max_features":max_features,
    'max_depth':max_depth,
    'min_samples_split':min_samples_split,
    'min_samples_leaf':min_samples_leaf,
    'n_estimators':n_estimators
}



rf = RandomForestClassifier()
rf_grid = RandomizedSearchCV(estimator=rf,param_distributions=params,n_iter=100,cv=3,verbose=2)
rf_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=   0.7s
# ...

# %%
rf_grid.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 2,
#  'min_samples_leaf': 5,
#  'max_features': 'sqrt',
#  'max_depth': 10}

# %%
RF=RandomForestClassifier(n_estimators=200,max_depth =10,max_features ='sqrt',min_samples_leaf=5,min_samples_split=2)
RF.fit(x_train,y_train)
new_pred = RF.predict(x_test)
score = f1_score(y_true=y_test,y_pred=new_pred)
accuracy = accuracy_score(y_true=y_test,y_pred=new_pred)
precision = precision_score(y_true=y_test,y_pred=new_pred)
recall = recall_score(y_true=y_test,y_pred=new_pred)
result2['Randomized_RF'] = [np.round(score,3),np.round(accuracy,3),np.round(precision,3),np.round(recall,3)]

# %%
n_estimators = [100,200,300,500,1000]
max_depth = [None,2,5,10]
min_samples_split = [2,5,10]
min_samples_leaf = [1,2,5]
max_features = ['auto','log2','sqrt']

params = {
    "max_features":max_features,
    'max_depth':max_depth,
    'min_samples_split':min_samples_split,
    'min_samples_leaf':min_samples_leaf,
    'n_estimators':n_estimators
}



rf = RandomForestClassifier()
rf_grid = GridSearchCV(estimator=rf,param_grid=params,cv=3,verbose=2)
rf_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 540 candidates, totalling 1620 fits
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.3s
# ...

# %%
rf_grid.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 'auto',
#  'min_samples_leaf': 5,
#  'min_samples_split': 5,
#  'n_estimators': 500}

# %%
RFG=RandomForestClassifier(n_estimators=500,max_depth =10,max_features ='auto',min_samples_leaf=5,min_samples_split=5)
RFG.fit(x_train,y_train)
new_predd = RFG.predict(x_test)
score = f1_score(y_true=y_test,y_pred=new_predd)
accuracy = accuracy_score(y_true=y_test,y_pred=new_predd)
precision = precision_score(y_true=y_test,y_pred=new_predd)
recall = recall_score(y_true=y_test,y_pred=new_predd)
result2['Grid_RF'] = [np.round(score,3),np.round(accuracy,3),np.round(precision,3),np.round(recall,3)]

# %%
plot_roc_curve(RFG,x_test,y_test)
plt.show()
# Out:
# C:\Users\IsoorI\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.

# %%
cm = sns.light_palette("green", as_cmap=True)

result2.T.style.highlight_max(color='lightgreen')
# Out:
# <style type="text/css">
# #T_0ba64_row8_col0, #T_0ba64_row8_col1, #T_0ba64_row8_col2, #T_0ba64_row8_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0ba64">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ba64_level0_col0" class="col_heading level0 col0" >SCORE</th>
#       <th id="T_0ba64_level0_col1" class="col_heading level0 col1" >ACCURACY</th>
#       <th id="T_0ba64_level0_col2" class="col_heading level0 col2" >PRECISION</th>
#       <th id="T_0ba64_level0_col3" class="col_heading level0 col3" >RECALL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ba64_level0_row0" class="row_heading level0 row0" >LogisticRegression</th>
#       <td id="T_0ba64_row0_col0" class="data row0 col0" >0.826000</td>
#       <td id="T_0ba64_row0_col1" class="data row0 col1" >0.813000</td>
#       <td id="T_0ba64_row0_col2" class="data row0 col2" >0.850000</td>
# ...

# %%
plot_roc_curve(RFG,x_test,y_test)
plt.show()
# Out:
# C:\Users\IsoorI\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning:
#
# Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.

# %%
cn = confusion_matrix(y_test,new_predd)
sns.heatmap(cn,annot=True,cbar=False)
plt.xlabel('True Label')
plt.ylabel("Predicted Label")
plt.show()
